# %% [markdown]
# # 3. Examples for apatite saturation temperature (AST) calculation

# %% [markdown]
# Calculate apatite saturation temperature using empirical equation of Harrison & Watson (1984) https://doi.org/10.1016/0016-7037(84)90403-4

# %%
import pyAp.ApSatTemp as calc_AST

# %% [markdown]
# Inputs are SiO$_{2}$ concentration in the melt, and P$_{2}$O$_{5}$ concentration in the melt

# %% [markdown]
# When wrong input values are used. For example, one uses concetration (conc) in the incorrect mass fraction (0<conc<1) rather than the correct weight percent (1<conc<100):

# %%
calc_AST.AST(0.55,0.003)
# Out:
# >> Warning: Concentrations are expressed as mass fractions.
#  Multiply them by 100 to convert into percentage!
# nan

# %% [markdown]
# When correct input values are used:

# %%
calc_AST.AST(55,0.3)
# Out:
# 849.3629335400316
